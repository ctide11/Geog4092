# %%
Elements = ["roads", "cities", "counties", "states"]
#This is a string

# %%
print(Elements)
# Out:
# ['roads', 'cities', 'counties', 'states']

# %%
for Element in Elements:
    print(Element)
#Elements in list form
# Out:
# roads
# cities
# counties
# states

# %%
ughempty = []
ughempty = ughempty + ["roads.txt", "cities.txt", "counties.txt", "states.txt"]
print(ughempty)
#empty list adding elements.txt
# Out:
# ['roads.txt', 'cities.txt', 'counties.txt', 'states.txt']

# %%
import math
from math import pi

# %%
print(pi)
#testing to make sure the import worked correctly for pi
# Out:
# 3.141592653589793

# %%
pi_time = []

cycle = 0
while cycle < 10000:
    pi_time.append(cycle)
    cycle = cycle + math.pi ** 1
    
if cycle > 10000:
    'break'

# %%
print('my final list is: ', pi_time, 'And the final cycle is: ', cycle)
# Out:
# my final list is:  [0, 3.141592653589793, 6.283185307179586, 9.42477796076938, 12.566370614359172, 15.707963267948966, 18.84955592153876, 21.991148575128552, 25.132741228718345, 28.274333882308138, 31.41592653589793, 34.55751918948772, 37.69911184307752, 40.840704496667314, 43.98229715025711, 47.12388980384691, 50.265482457436704, 53.4070751110265, 56.5486677646163, 59.690260418206094, 62.83185307179589, 65.97344572538569, 69.11503837897548, 72.25663103256528, 75.39822368615508, 78.53981633974487, 81.68140899333467, 84.82300164692447, 87.96459430051426, 91.10618695410406, 94.24777960769386, 97.38937226128365, 100.53096491487345, 103.67255756846325, 106.81415022205304, 109.95574287564284, 113.09733552923264, 116.23892818282243, 119.38052083641223, 122.52211349000203, 125.66370614359182, 128.80529879718162, 131.9468914507714, 135.08848410436119, 138.23007675795097, 141.37166941154075, 144.51326206513053, 147.65485471872032, 150.7964473723101, 153.93804002589988, 157.07963267948966, 160
# ...
